# %% [markdown]
# ## Load saved module performance from file

# %%
import pickle
import matplotlib.pyplot as plt

filename = r"C:\Users\Chandralekha Podili\Downloads\Default-Credit-Cards-main\Default-Credit-Cards-main\all_metrics.sav"
 
metrics = pickle.load(open(filename, 'rb'))
 
print("\n", "metrics after reloading", "\n", 50 * "-", "\n", metrics)
# Out:
#  metrics after reloading
#  --------------------------------------------------
#                  SVM Naive bayes LogisticReg   Bagging RandomForest  Boosting
# accuracy   0.795111       0.742       0.806  0.805333     0.812667     0.804
# precision  0.551773     0.43806    0.621514  0.617822        0.625  0.631702
# recall     0.390955     0.58995    0.313568  0.313568      0.38191  0.272362

# %%
fig, ax = plt.subplots(figsize=(15,5))
metrics.plot(kind='bar', ax=ax)
plt.grid()
